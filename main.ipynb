# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/aboic/OneDrive/Documents/year_hw4_db.csv", names = ["year_of_release", "count"])
df
# Out:
#     year_of_release  count
# 0              2006      3
# 1              2007      1
# 2              2008      3
# 3              2009     11
# 4              2010     10
# 5              2011     16
# 6              2012     24
# 7              2013     34
# 8              2014    114
# 9              2015    163
# 10             2016    303
# 11             2017    376
# 12             2018    421
# 13             2019    440
# 14             2020    518
# 15             2021    698
# 16             2022    729
# 17             2023    733
# 18             2024   1101
# 19             2025    956
# 20             2026      2
# 21             2027      1
# 22             2028      3
# 23             2034      1

# %%
colors = plt.cm.viridis(np.linspace(0, 1, len(df["year_of_release"])))
plt.grid(True, linestyle='--', zorder=1)
plt.bar(df["year_of_release"], df["count"], color= colors, zorder=2)
plt.title("Number of Steam Releases per Year")
# Out:
# Text(0.5, 1.0, 'Number of Steam Releases per Year')
